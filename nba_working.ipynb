# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
#importing request to make sure url works
import requests
#using beautiful soup to web scrape data from basketball reference
from bs4 import BeautifulSoup

import warnings
# Out:
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# The requests library can send a GET request to the 2022 spurs page
spurs_request = requests.get('https://www.basketball-reference.com/teams/SAS/2022.html')

# BeautifulSoup library parses the content of an HTML document, in this case wiz_res
spurs_soup = BeautifulSoup(spurs_request.content, 'lxml')

# BeautifulSoup's .find() method searches for a tag and specified attributes, 
# returning the first match 
spurs_pergame = spurs_soup.find(name = 'table', attrs = {'id' : 'per_game'})

# %%
def get_pergame():
    # Creating a list of dictionaries to then convert into a Pandas Dataframe
    spurs_stats = []

    for row in spurs_pergame.find_all('tr')[1:]:  # Excluding the first 'tr', since that's the table's title head

        player = {}
        player['Name'] = row.find('a').text.strip()
        player['Age'] = row.find('td', {'data-stat' : 'age'}).text
        player['GP'] = row.find('td', {'data-stat' : 'g'}).text
        player['Points_PG'] = row.find('td', {'data-stat' : 'pts_per_g'}).text
        player['Field_Goal_percent'] = row.find('td', {'data-stat' : 'fg_pct'}).text
        player['3PT_percent'] = row.find('td', {'data-stat' : 'fg3_pct'}).text
        player['2PT_percent'] = row.find('td', {'data-stat' : 'fg2_pct'}).text
        player['EFG_percent'] = row.find('td', {'data-stat' : 'efg_pct'}).text
        player['FTA'] = row.find('td', {'data-stat' : 'fta_per_g'}).text 
        player['FT%'] = row.find('td', {'data-stat' : 'ft_pct'}).text
        player['ORB'] = row.find('td', {'data-stat' : 'orb_per_g'}).text
        player['DRB'] = row.find('td', {'data-stat' : 'drb_per_g'}).text
        player['Total_Rebounds_PG'] = row.find('td', {'data-stat' : 'trb_per_g'}).text
        player['Assists_PG'] = row.find('td', {'data-stat' : 'ast_per_g'}).text
        player['Steals_PG'] = row.find('td', {'data-stat' : 'stl_per_g'}).text
        player['Blocks_PG'] = row.find('td', {'data-stat' : 'blk_per_g'}).text
        player['Turnovers_PG'] = row.find('td', {'data-stat' : 'tov_per_g'}).text
        player['Fouls_PG'] = row.find('td', {'data-stat' : 'pf_per_g'}).text
        player['Min_PG'] = row.find('td', {'data-stat' : 'mp_per_g'}).text
        spurs_stats.append(player)

    pergamestats = pd.DataFrame(spurs_stats)

    return pergamestats.set_index('Name').sort_index(ascending=True)

# %%
pergamestats = get_pergame()
pergamestats
# Out:
#                     Age  GP Points_PG Field_Goal_percent 3PT_percent  \
# Name
# Anthony Lamb         24   2       0.0               .000        .000
# Bryn Forbes          28  40       9.1               .432        .417
# Dejounte Murray      25  68      21.1               .462        .327
# Derrick White        27  49      14.4               .426        .314
# Devin Vassell        21  71      12.3               .427        .361
# Devontae Cacok       25  15       3.1               .677
# Doug McDermott       30  51      11.3               .462        .422
# Drew Eubanks         24  49       4.7               .528        .125
# Jakob Poeltl         26  68      13.5               .618       1.000
# Jaylen Morris        26   3       0.7               .000        .000
# Jock Landale         26  54       4.9               .495        .326
# Joe Wieskamp         22  29       2.1               .357        .326
# Josh Richardson      28  21      11.4               .429        .444
# Joshua Primo         19  50       5.8               .374        .307
# Juancho Hernangómez  26   5       1.4               .333        .000
# Keita Bates-Diop     26  59       5.7               .517        .309
# Keldon Johnson       22  75      17.0               .466        .398
# Lonnie Walker IV     23  70      12.1               .407        .314
# Romeo Langford       22   4       2.8               .571        .000
# Thaddeus Young       33  26       6.1               .578        .000
# Tomáš Satoranský     30   1       3.0
# Tre Jones            22  69       6.0               .490        .196
# Tyler Johnson        29   3       2.0               .200        .333
# Zach Collins         24  28       7.8               .490        .341
#
#                     2PT_percent EFG_percent  FTA   FT%  ORB  DRB  \
# Name
# Anthony Lamb                           .000  0.0        0.0  0.5
# Bryn Forbes                .448        .539  1.2  .898  0.1  1.5
# Dejounte Murray            .504        .500  3.6  .794  1.2  7.1
# Derrick White              .519        .497  3.3  .869  0.5  3.0
# Devin Vassell              .492        .516  1.4  .838  0.6  3.7
# Devontae Cacok             .677        .677  0.5  .571  0.5  2.3
# Doug McDermott             .512        .578  1.0  .784  0.4  1.9
# Drew Eubanks               .550        .531  1.6  .747  1.3  2.7
# Jakob Poeltl               .618        .619  2.8  .495  3.9  5.5
# Jaylen Morris              .000        .000  1.3  .500  0.0  0.7
# Jock Landale               .626        .566  0.8  .829  1.2  1.4
# Joe Wieskamp               .462        .482  0.4  .538  0.1  0.3
# Josh Richardson            .416        .534  1.8  .946  0.8  2.1
# Joshua Primo               .444        .452  1.2  .746  0.6  1.6
# Juancho Hernangómez        .667        .333  0.8  .750  0.8  2.2
# Keita Bates-Diop           .572        .549  1.0  .754  1.1  2.9
# Keldon Johnson             .510        .545  3.1  .756  1.1  5.0
# Lonnie Walker IV           .487        .480  2.1  .784  0.3  2.3
# Romeo Langford             .800        .571  2.0  .375  0.0  1.0
# Thaddeus Young             .602        .578  0.8  .455  1.5  2.0
# Tomáš Satoranský                             4.0  .750  0.0  1.0
# Tre Jones                  .542        .504  1.3  .780  0.4  1.8
# Tyler Johnson              .000        .300  0.0        0.7  1.3
# Zach Collins               .544        .535  2.3  .800  1.6  3.8
#
#                     Total_Rebounds_PG Assists_PG Steals_PG Blocks_PG  \
# Name
# Anthony Lamb                      0.5        1.0       0.0       0.0
# Bryn Forbes                       1.6        1.0       0.4       0.1
# Dejounte Murray                   8.3        9.2       2.0       0.3
# Derrick White                     3.5        5.6       1.0       0.9
# Devin Vassell                     4.3        1.9       1.1       0.6
# Devontae Cacok                    2.8        0.4       0.5       0.5
# Doug McDermott                    2.3        1.3       0.3       0.1
# Drew Eubanks                      4.0        1.0       0.3       0.6
# Jakob Poeltl                      9.3        2.8       0.7       1.7
# Jaylen Morris                     0.7        0.7       0.0       0.0
# Jock Landale                      2.6        0.8       0.2       0.3
# Joe Wieskamp                      0.5        0.3       0.1       0.1
# Josh Richardson                   2.9        2.3       1.0       0.3
# Joshua Primo                      2.3        1.6       0.4       0.5
# Juancho Hernangómez               3.0        0.6       0.2       0.2
# Keita Bates-Diop                  3.9        0.7       0.5       0.2
# Keldon Johnson                    6.1        2.1       0.8       0.2
# Lonnie Walker IV                  2.6        2.2       0.6       0.3
# Romeo Langford                    1.0        0.5       0.3       0.0
# Thaddeus Young                    3.6        2.3       0.9       0.3
# Tomáš Satoranský                  1.0        0.0       0.0       0.0
# Tre Jones                         2.2        3.4       0.6       0.1
# Tyler Johnson                     2.0        1.7       0.7       0.7
# Zach Collins                      5.5        2.2       0.5       0.8
#
#                     Turnovers_PG Fouls_PG Min_PG
# Name
# Anthony Lamb                 0.0      0.0    4.0
# Bryn Forbes                  0.8      1.1   16.9
# Dejounte Murray              2.6      2.0   34.8
# Derrick White                1.8      2.4   30.3
# Devin Vassell                0.8      2.0   27.3
# Devontae Cacok               0.2      1.1    8.1
# Doug McDermott               0.8      1.5   24.0
# Drew Eubanks                 0.9      1.2   12.1
# Jakob Poeltl                 1.6      3.1   29.0
# Jaylen Morris                0.3      0.7    5.3
# Jock Landale                 0.6      1.0   10.9
# Joe Wieskamp                 0.1      0.5    7.1
# Josh Richardson              1.3      1.6   24.4
# Joshua Primo                 1.1      1.6   19.3
# Juancho Hernangómez          0.4      0.0   10.2
# Keita Bates-Diop             0.8      1.0   16.2
# Keldon Johnson               1.2      2.0   31.9
# Lonnie Walker IV             1.0      1.4   23.0
# Romeo Langford               0.0      0.3   10.8
# Thaddeus Young               1.2      1.5   14.2
# Tomáš Satoranský             0.0      0.0    9.0
# Tre Jones                    0.7      1.1   16.6
# Tyler Johnson                0.3      1.0   17.7
# Zach Collins                 1.6      2.4   17.9

# %%
def get_adv():
    spurs_adv = spurs_soup.find(name = 'table', attrs = {'id' : 'advanced'})

    # Creating a list of dictionaries to then convert into a Pandas Dataframe
    spurs_adv_stats = []

    for row in spurs_adv.find_all('tr')[1:]:  # Excluding the first 'tr', since that's the table's title head

        adv_player = {}
        adv_player['Name'] = row.find('a').text.strip()
        adv_player['Age'] = row.find('td', {'data-stat' : 'age'}).text
        adv_player['PER'] = row.find('td', {'data-stat' : 'per'}).text
        adv_player['TS_percent'] = row.find('td', {'data-stat' : 'ts_pct'}).text
        adv_player['3PAr'] = row.find('td', {'data-stat' : 'fg3a_per_fga_pct'}).text
        adv_player['FTr'] = row.find('td', {'data-stat' : 'fta_per_fga_pct'}).text
        adv_player['ORB_percent'] = row.find('td', {'data-stat' : 'orb_pct'}).text
        adv_player['DRB_percent'] = row.find('td', {'data-stat' : 'drb_pct'}).text
        adv_player['TRB_percent'] = row.find('td', {'data-stat' : 'trb_pct'}).text
        adv_player['AST_percent'] = row.find('td', {'data-stat' : 'ast_pct'}).text
        adv_player['STL_percent'] = row.find('td', {'data-stat' : 'stl_pct'}).text
        adv_player['BLK_percent'] = row.find('td', {'data-stat' : 'blk_pct'}).text
        adv_player['TOV_percent'] = row.find('td', {'data-stat' : 'tov_pct'}).text
        adv_player['USG_percent'] = row.find('td', {'data-stat' : 'usg_pct'}).text
        adv_player['OWS'] = row.find('td', {'data-stat' : 'ows'}).text
        adv_player['DWS'] = row.find('td', {'data-stat' : 'dws'}).text
        adv_player['WS'] = row.find('td', {'data-stat' : 'ws'}).text
        adv_player['OBPM'] = row.find('td', {'data-stat' : 'obpm'}).text
        adv_player['DBPM'] = row.find('td', {'data-stat' : 'dbpm'}).text
        adv_player['BPM'] = row.find('td', {'data-stat' : 'bpm'}).text
        adv_player['VORP'] = row.find('td', {'data-stat' : 'vorp'}).text


        spurs_adv_stats.append(adv_player)

    advstats = pd.DataFrame(spurs_adv_stats)
    return advstats.set_index('Name').sort_index(ascending=True)

# %%
advstats = get_adv()
advstats
# Out:
#                     Age    PER TS_percent   3PAr    FTr ORB_percent  \
# Name
# Anthony Lamb         24   -0.5       .000  1.000   .000         0.0
# Bryn Forbes          28   12.4       .572   .510   .166         0.6
# Dejounte Murray      25   22.3       .533   .237   .199         3.5
# Derrick White        27   15.7       .551   .453   .281         1.8
# Devin Vassell        21   13.3       .540   .497   .130         2.4
# Devontae Cacok       25   20.2       .675   .000   .226         6.9
# Doug McDermott       30   11.4       .593   .551   .110         1.5
# Drew Eubanks         24   16.0       .588   .050   .497        11.2
# Jakob Poeltl         26   20.8       .613   .002   .287        13.9
# Jaylen Morris        26  -11.4       .129   .333   .667         0.0
# Jock Landale         26   16.0       .597   .436   .201        11.1
# Joe Wieskamp         22    7.1       .494   .768   .232         2.0
# Josh Richardson      28   14.0       .577   .471   .194         3.2
# Joshua Primo         19    7.1       .487   .507   .219         3.5
# Juancho Hernangómez  26    9.0       .451   .500   .667         8.2
# Keita Bates-Diop     26   12.4       .578   .209   .232         6.8
# Keldon Johnson       22   15.2       .574   .395   .231         3.5
# Lonnie Walker IV     23   12.3       .512   .462   .194         1.2
# Romeo Langford       22    8.1       .523   .286  1.143         0.0
# Thaddeus Young       33   18.6       .574   .039   .172        11.3
# Tomáš Satoranský     30   12.8       .852                       0.0
# Tre Jones            22   15.0       .545   .150   .268         2.6
# Tyler Johnson        29    5.5       .300   .600   .000         3.9
# Zach Collins         24   16.4       .594   .265   .419         9.5
#
#                     DRB_percent TRB_percent AST_percent STL_percent  \
# Name
# Anthony Lamb               13.2         6.6        27.9         0.0
# Bryn Forbes                 9.2         4.9         8.6         1.2
# Dejounte Murray            21.6        12.5        40.6         2.8
# Derrick White              10.5         6.1        25.2         1.6
# Devin Vassell              14.3         8.3         9.7         1.9
# Devontae Cacok             29.7        18.2         6.9         3.2
# Doug McDermott              8.4         4.9         7.3         0.5
# Drew Eubanks               23.4        17.3        11.1         1.0
# Jakob Poeltl               20.0        16.9        14.0         1.1
# Jaylen Morris              13.2         6.6        14.0         0.0
# Jock Landale               13.5        12.3        10.6         0.8
# Joe Wieskamp                5.2         3.6         5.5         0.9
# Josh Richardson             9.1         6.1        13.0         2.1
# Joshua Primo                8.9         6.1        10.6         1.0
# Juancho Hernangómez        22.8        15.4         6.9         0.9
# Keita Bates-Diop           18.7        12.7         5.7         1.4
# Keldon Johnson             16.7        10.0         9.5         1.2
# Lonnie Walker IV           10.7         5.9        13.4         1.3
# Romeo Langford              9.8         4.9         5.8         1.1
# Thaddeus Young             15.1        13.2        22.9         3.0
# Tomáš Satoranský           11.7         5.8         0.0         0.0
# Tre Jones                  11.6         7.1        27.0         1.8
# Tyler Johnson               8.0         5.9        11.0         1.8
# Zach Collins               22.5        16.0        16.3         1.2
#
#                     BLK_percent TOV_percent USG_percent   OWS  DWS    WS  \
# Name
# Anthony Lamb                0.0         0.0        10.6   0.0  0.0   0.0
# Bryn Forbes                 0.4         9.4        21.9   0.3  0.4   0.7
# Dejounte Murray             0.8        11.8        27.3   3.9  3.4   7.3
# Derrick White               2.4        12.0        20.7   2.0  1.3   3.3
# Devin Vassell               1.8         6.7        18.9   1.3  2.0   3.3
# Devontae Cacok              4.9         8.1        12.9   0.3  0.3   0.5
# Doug McDermott              0.4         8.1        18.3   1.1  0.5   1.6
# Drew Eubanks                4.2        19.2        17.0   0.6  0.8   1.4
# Jakob Poeltl                5.0        12.7        18.3   4.4  2.5   6.9
# Jaylen Morris               0.0        11.4        23.1  -0.1  0.0  -0.1
# Jock Landale                2.0        12.3        18.1   1.0  0.4   1.5
# Joe Wieskamp                1.2         3.1        13.1   0.1  0.1   0.1
# Josh Richardson             1.0        11.5        19.3   0.5  0.4   1.0
# Joshua Primo                2.0        16.1        15.4  -0.6  0.6   0.0
# Juancho Hernangómez         1.6        20.5         8.1   0.0  0.1   0.1
# Keita Bates-Diop            1.2        13.4        14.8   0.6  1.0   1.6
# Keldon Johnson              0.5         7.6        21.3   2.9  2.0   4.9
# Lonnie Walker IV            1.0         7.9        23.6   0.1  1.1   1.2
# Romeo Langford              0.0         0.0        10.3   0.0  0.0   0.0
# Thaddeus Young              1.6        17.9        19.1   0.5  0.5   1.0
# Tomáš Satoranský            0.0         0.0         8.3   0.0  0.0   0.0
# Tre Jones                   0.5        10.8        15.6   1.9  0.9   2.9
# Tyler Johnson               3.2         9.1         8.8   0.0  0.0   0.0
# Zach Collins                3.8        19.7        19.2   0.6  0.7   1.2
#
#                       OBPM  DBPM    BPM  VORP
# Name
# Anthony Lamb          -6.2  -1.8   -8.0   0.0
# Bryn Forbes           -0.3  -1.3   -1.6   0.1
# Dejounte Murray        3.7   1.7    5.4   4.4
# Derrick White          1.2   0.6    1.8   1.4
# Devin Vassell         -0.5   0.0   -0.5   0.7
# Devontae Cacok         0.7   3.5    4.2   0.2
# Doug McDermott        -0.4  -2.1   -2.5  -0.1
# Drew Eubanks          -1.9   0.7   -1.2   0.1
# Jakob Poeltl           0.9   0.7    1.6   1.7
# Jaylen Morris        -15.8  -5.7  -21.5  -0.1
# Jock Landale           0.7  -1.1   -0.4   0.2
# Joe Wieskamp          -2.9  -1.1   -3.9  -0.1
# Josh Richardson        0.1  -0.3   -0.2   0.2
# Joshua Primo          -3.8  -1.1   -5.0  -0.7
# Juancho Hernangómez   -2.4  -0.1   -2.5   0.0
# Keita Bates-Diop      -2.1  -0.5   -2.6  -0.1
# Keldon Johnson         0.7  -1.2   -0.5   0.9
# Lonnie Walker IV      -1.2  -1.3   -2.5  -0.2
# Romeo Langford        -3.8  -0.4   -4.1   0.0
# Thaddeus Young         0.5   1.8    2.4   0.4
# Tomáš Satoranský       0.8  -2.1   -1.3   0.0
# Tre Jones             -0.9   0.4   -0.5   0.4
# Tyler Johnson         -4.9   1.1   -3.8   0.0
# Zach Collins          -1.2   1.0   -0.2   0.2

# %%
def get_salaries():
# Was unable to webscrape salaries so i pulled the data into a csv and used pandas to convert to dataframe
# salaries = spurs_soup.find(name = 'table', attrs = {'id' : 'salaries2'})

    salaries = pd.read_csv('salaries - Sheet1.csv')
    return salaries.set_index('Name').sort_index(ascending=True)

# %%
salaries = get_salaries()
salaries
# Out:
#                           Salary
# Name
# Anthony Lamb             $85,578
# Bryn Forbes           $4,500,000
# Dejounte Murray      $15,428,880
# Derrick White        $15,178,571
# Devin Vassell         $4,235,160
# Devontae Cacok          $364,533
# Doug McDermott       $13,750,000
# Drew Eubanks          $2,239,820
# Jakob Poeltl          $8,750,000
# Jaylen Morris            $95,930
# Jock Landale            $925,258
# Joe Wieskamp            $202,068
# Josh Richardson      $11,615,328
# Joshua Primo          $3,946,800
# Juancho Hernangómez   $6,175,440
# Keita Bates-Diop      $1,729,217
# Keldon Johnson        $2,145,720
# Lonnie Walker IV      $4,447,896
# Romeo Langford        $3,804,360
# Thaddeus Young       $14,190,000
# Tomáš Satoranský      $9,531,881
# Tre Jones             $1,517,981
# Tyler Johnson           $128,709
# Zach Collins          $7,000,000

# %%
spurs_df = pd.concat([pergamestats, advstats, salaries], axis=1)
spurs_df
# Out:
#                     Age  GP Points_PG Field_Goal_percent 3PT_percent  \
# Name
# Anthony Lamb         24   2       0.0               .000        .000
# Bryn Forbes          28  40       9.1               .432        .417
# Dejounte Murray      25  68      21.1               .462        .327
# Derrick White        27  49      14.4               .426        .314
# Devin Vassell        21  71      12.3               .427        .361
# Devontae Cacok       25  15       3.1               .677
# Doug McDermott       30  51      11.3               .462        .422
# Drew Eubanks         24  49       4.7               .528        .125
# Jakob Poeltl         26  68      13.5               .618       1.000
# Jaylen Morris        26   3       0.7               .000        .000
# Jock Landale         26  54       4.9               .495        .326
# Joe Wieskamp         22  29       2.1               .357        .326
# Josh Richardson      28  21      11.4               .429        .444
# Joshua Primo         19  50       5.8               .374        .307
# Juancho Hernangómez  26   5       1.4               .333        .000
# Keita Bates-Diop     26  59       5.7               .517        .309
# Keldon Johnson       22  75      17.0               .466        .398
# Lonnie Walker IV     23  70      12.1               .407        .314
# Romeo Langford       22   4       2.8               .571        .000
# Thaddeus Young       33  26       6.1               .578        .000
# Tomáš Satoranský     30   1       3.0
# Tre Jones            22  69       6.0               .490        .196
# Tyler Johnson        29   3       2.0               .200        .333
# Zach Collins         24  28       7.8               .490        .341
#
#                     2PT_percent EFG_percent  FTA   FT%  ORB  ... TOV_percent  \
# Name                                                         ...
# Anthony Lamb                           .000  0.0        0.0  ...         0.0
# Bryn Forbes                .448        .539  1.2  .898  0.1  ...         9.4
# Dejounte Murray            .504        .500  3.6  .794  1.2  ...        11.8
# Derrick White              .519        .497  3.3  .869  0.5  ...        12.0
# Devin Vassell              .492        .516  1.4  .838  0.6  ...         6.7
# Devontae Cacok             .677        .677  0.5  .571  0.5  ...         8.1
# Doug McDermott             .512        .578  1.0  .784  0.4  ...         8.1
# Drew Eubanks               .550        .531  1.6  .747  1.3  ...        19.2
# Jakob Poeltl               .618        .619  2.8  .495  3.9  ...        12.7
# Jaylen Morris              .000        .000  1.3  .500  0.0  ...        11.4
# Jock Landale               .626        .566  0.8  .829  1.2  ...        12.3
# Joe Wieskamp               .462        .482  0.4  .538  0.1  ...         3.1
# Josh Richardson            .416        .534  1.8  .946  0.8  ...        11.5
# Joshua Primo               .444        .452  1.2  .746  0.6  ...        16.1
# Juancho Hernangómez        .667        .333  0.8  .750  0.8  ...        20.5
# Keita Bates-Diop           .572        .549  1.0  .754  1.1  ...        13.4
# Keldon Johnson             .510        .545  3.1  .756  1.1  ...         7.6
# Lonnie Walker IV           .487        .480  2.1  .784  0.3  ...         7.9
# Romeo Langford             .800        .571  2.0  .375  0.0  ...         0.0
# Thaddeus Young             .602        .578  0.8  .455  1.5  ...        17.9
# Tomáš Satoranský                             4.0  .750  0.0  ...         0.0
# Tre Jones                  .542        .504  1.3  .780  0.4  ...        10.8
# Tyler Johnson              .000        .300  0.0        0.7  ...         9.1
# Zach Collins               .544        .535  2.3  .800  1.6  ...        19.7
#
#                     USG_percent   OWS  DWS    WS   OBPM  DBPM    BPM  VORP  \
# Name
# Anthony Lamb               10.6   0.0  0.0   0.0   -6.2  -1.8   -8.0   0.0
# Bryn Forbes                21.9   0.3  0.4   0.7   -0.3  -1.3   -1.6   0.1
# Dejounte Murray            27.3   3.9  3.4   7.3    3.7   1.7    5.4   4.4
# Derrick White              20.7   2.0  1.3   3.3    1.2   0.6    1.8   1.4
# Devin Vassell              18.9   1.3  2.0   3.3   -0.5   0.0   -0.5   0.7
# Devontae Cacok             12.9   0.3  0.3   0.5    0.7   3.5    4.2   0.2
# Doug McDermott             18.3   1.1  0.5   1.6   -0.4  -2.1   -2.5  -0.1
# Drew Eubanks               17.0   0.6  0.8   1.4   -1.9   0.7   -1.2   0.1
# Jakob Poeltl               18.3   4.4  2.5   6.9    0.9   0.7    1.6   1.7
# Jaylen Morris              23.1  -0.1  0.0  -0.1  -15.8  -5.7  -21.5  -0.1
# Jock Landale               18.1   1.0  0.4   1.5    0.7  -1.1   -0.4   0.2
# Joe Wieskamp               13.1   0.1  0.1   0.1   -2.9  -1.1   -3.9  -0.1
# Josh Richardson            19.3   0.5  0.4   1.0    0.1  -0.3   -0.2   0.2
# Joshua Primo               15.4  -0.6  0.6   0.0   -3.8  -1.1   -5.0  -0.7
# Juancho Hernangómez         8.1   0.0  0.1   0.1   -2.4  -0.1   -2.5   0.0
# Keita Bates-Diop           14.8   0.6  1.0   1.6   -2.1  -0.5   -2.6  -0.1
# Keldon Johnson             21.3   2.9  2.0   4.9    0.7  -1.2   -0.5   0.9
# Lonnie Walker IV           23.6   0.1  1.1   1.2   -1.2  -1.3   -2.5  -0.2
# Romeo Langford             10.3   0.0  0.0   0.0   -3.8  -0.4   -4.1   0.0
# Thaddeus Young             19.1   0.5  0.5   1.0    0.5   1.8    2.4   0.4
# Tomáš Satoranský            8.3   0.0  0.0   0.0    0.8  -2.1   -1.3   0.0
# Tre Jones                  15.6   1.9  0.9   2.9   -0.9   0.4   -0.5   0.4
# Tyler Johnson               8.8   0.0  0.0   0.0   -4.9   1.1   -3.8   0.0
# Zach Collins               19.2   0.6  0.7   1.2   -1.2   1.0   -0.2   0.2
#
#                           Salary
# Name
# Anthony Lamb             $85,578
# Bryn Forbes           $4,500,000
# Dejounte Murray      $15,428,880
# Derrick White        $15,178,571
# Devin Vassell         $4,235,160
# Devontae Cacok          $364,533
# Doug McDermott       $13,750,000
# Drew Eubanks          $2,239,820
# Jakob Poeltl          $8,750,000
# Jaylen Morris            $95,930
# Jock Landale            $925,258
# Joe Wieskamp            $202,068
# Josh Richardson      $11,615,328
# Joshua Primo          $3,946,800
# Juancho Hernangómez   $6,175,440
# Keita Bates-Diop      $1,729,217
# Keldon Johnson        $2,145,720
# Lonnie Walker IV      $4,447,896
# Romeo Langford        $3,804,360
# Thaddeus Young       $14,190,000
# Tomáš Satoranský      $9,531,881
# Tre Jones             $1,517,981
# Tyler Johnson           $128,709
# Zach Collins          $7,000,000
#
# [24 rows x 39 columns]

# %%
# We now have all of our data acquired and joined together!
spurs_df
# Out:
#                     Age  GP Points_PG Field_Goal_percent 3PT_percent  \
# Name
# Anthony Lamb         24   2       0.0               .000        .000
# Bryn Forbes          28  40       9.1               .432        .417
# Dejounte Murray      25  68      21.1               .462        .327
# Derrick White        27  49      14.4               .426        .314
# Devin Vassell        21  71      12.3               .427        .361
# Devontae Cacok       25  15       3.1               .677
# Doug McDermott       30  51      11.3               .462        .422
# Drew Eubanks         24  49       4.7               .528        .125
# Jakob Poeltl         26  68      13.5               .618       1.000
# Jaylen Morris        26   3       0.7               .000        .000
# Jock Landale         26  54       4.9               .495        .326
# Joe Wieskamp         22  29       2.1               .357        .326
# Josh Richardson      28  21      11.4               .429        .444
# Joshua Primo         19  50       5.8               .374        .307
# Juancho Hernangómez  26   5       1.4               .333        .000
# Keita Bates-Diop     26  59       5.7               .517        .309
# Keldon Johnson       22  75      17.0               .466        .398
# Lonnie Walker IV     23  70      12.1               .407        .314
# Romeo Langford       22   4       2.8               .571        .000
# Thaddeus Young       33  26       6.1               .578        .000
# Tomáš Satoranský     30   1       3.0
# Tre Jones            22  69       6.0               .490        .196
# Tyler Johnson        29   3       2.0               .200        .333
# Zach Collins         24  28       7.8               .490        .341
#
#                     2PT_percent EFG_percent  FTA   FT%  ORB  ... TOV_percent  \
# Name                                                         ...
# Anthony Lamb                           .000  0.0        0.0  ...         0.0
# Bryn Forbes                .448        .539  1.2  .898  0.1  ...         9.4
# Dejounte Murray            .504        .500  3.6  .794  1.2  ...        11.8
# Derrick White              .519        .497  3.3  .869  0.5  ...        12.0
# Devin Vassell              .492        .516  1.4  .838  0.6  ...         6.7
# Devontae Cacok             .677        .677  0.5  .571  0.5  ...         8.1
# Doug McDermott             .512        .578  1.0  .784  0.4  ...         8.1
# Drew Eubanks               .550        .531  1.6  .747  1.3  ...        19.2
# Jakob Poeltl               .618        .619  2.8  .495  3.9  ...        12.7
# Jaylen Morris              .000        .000  1.3  .500  0.0  ...        11.4
# Jock Landale               .626        .566  0.8  .829  1.2  ...        12.3
# Joe Wieskamp               .462        .482  0.4  .538  0.1  ...         3.1
# Josh Richardson            .416        .534  1.8  .946  0.8  ...        11.5
# Joshua Primo               .444        .452  1.2  .746  0.6  ...        16.1
# Juancho Hernangómez        .667        .333  0.8  .750  0.8  ...        20.5
# Keita Bates-Diop           .572        .549  1.0  .754  1.1  ...        13.4
# Keldon Johnson             .510        .545  3.1  .756  1.1  ...         7.6
# Lonnie Walker IV           .487        .480  2.1  .784  0.3  ...         7.9
# Romeo Langford             .800        .571  2.0  .375  0.0  ...         0.0
# Thaddeus Young             .602        .578  0.8  .455  1.5  ...        17.9
# Tomáš Satoranský                             4.0  .750  0.0  ...         0.0
# Tre Jones                  .542        .504  1.3  .780  0.4  ...        10.8
# Tyler Johnson              .000        .300  0.0        0.7  ...         9.1
# Zach Collins               .544        .535  2.3  .800  1.6  ...        19.7
#
#                     USG_percent   OWS  DWS    WS   OBPM  DBPM    BPM  VORP  \
# Name
# Anthony Lamb               10.6   0.0  0.0   0.0   -6.2  -1.8   -8.0   0.0
# Bryn Forbes                21.9   0.3  0.4   0.7   -0.3  -1.3   -1.6   0.1
# Dejounte Murray            27.3   3.9  3.4   7.3    3.7   1.7    5.4   4.4
# Derrick White              20.7   2.0  1.3   3.3    1.2   0.6    1.8   1.4
# Devin Vassell              18.9   1.3  2.0   3.3   -0.5   0.0   -0.5   0.7
# Devontae Cacok             12.9   0.3  0.3   0.5    0.7   3.5    4.2   0.2
# Doug McDermott             18.3   1.1  0.5   1.6   -0.4  -2.1   -2.5  -0.1
# Drew Eubanks               17.0   0.6  0.8   1.4   -1.9   0.7   -1.2   0.1
# Jakob Poeltl               18.3   4.4  2.5   6.9    0.9   0.7    1.6   1.7
# Jaylen Morris              23.1  -0.1  0.0  -0.1  -15.8  -5.7  -21.5  -0.1
# Jock Landale               18.1   1.0  0.4   1.5    0.7  -1.1   -0.4   0.2
# Joe Wieskamp               13.1   0.1  0.1   0.1   -2.9  -1.1   -3.9  -0.1
# Josh Richardson            19.3   0.5  0.4   1.0    0.1  -0.3   -0.2   0.2
# Joshua Primo               15.4  -0.6  0.6   0.0   -3.8  -1.1   -5.0  -0.7
# Juancho Hernangómez         8.1   0.0  0.1   0.1   -2.4  -0.1   -2.5   0.0
# Keita Bates-Diop           14.8   0.6  1.0   1.6   -2.1  -0.5   -2.6  -0.1
# Keldon Johnson             21.3   2.9  2.0   4.9    0.7  -1.2   -0.5   0.9
# Lonnie Walker IV           23.6   0.1  1.1   1.2   -1.2  -1.3   -2.5  -0.2
# Romeo Langford             10.3   0.0  0.0   0.0   -3.8  -0.4   -4.1   0.0
# Thaddeus Young             19.1   0.5  0.5   1.0    0.5   1.8    2.4   0.4
# Tomáš Satoranský            8.3   0.0  0.0   0.0    0.8  -2.1   -1.3   0.0
# Tre Jones                  15.6   1.9  0.9   2.9   -0.9   0.4   -0.5   0.4
# Tyler Johnson               8.8   0.0  0.0   0.0   -4.9   1.1   -3.8   0.0
# Zach Collins               19.2   0.6  0.7   1.2   -1.2   1.0   -0.2   0.2
#
#                           Salary
# Name
# Anthony Lamb             $85,578
# Bryn Forbes           $4,500,000
# Dejounte Murray      $15,428,880
# Derrick White        $15,178,571
# Devin Vassell         $4,235,160
# Devontae Cacok          $364,533
# Doug McDermott       $13,750,000
# Drew Eubanks          $2,239,820
# Jakob Poeltl          $8,750,000
# Jaylen Morris            $95,930
# Jock Landale            $925,258
# Joe Wieskamp            $202,068
# Josh Richardson      $11,615,328
# Joshua Primo          $3,946,800
# Juancho Hernangómez   $6,175,440
# Keita Bates-Diop      $1,729,217
# Keldon Johnson        $2,145,720
# Lonnie Walker IV      $4,447,896
# Romeo Langford        $3,804,360
# Thaddeus Young       $14,190,000
# Tomáš Satoranský      $9,531,881
# Tre Jones             $1,517,981
# Tyler Johnson           $128,709
# Zach Collins          $7,000,000
#
# [24 rows x 39 columns]

# %%
# Wrangle data into one function
def wrangle_spurs():
